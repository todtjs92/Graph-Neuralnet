# %% [markdown]
# <a href="https://colab.research.google.com/github/todtjs92/Graph-Neuralnet/blob/master/Graph_Community_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('g')
# Out:
# g

# %%
/content/drive/MyDrive/74023_2021_10_12.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/74023_2021_10_12.csv')

# %%
df
# Out:
#                            user_f_id  ...                                    product_title
# 0       009P43Kc7tTdx06F3BWmth3kZmr2  ...               특별한 날을 더 특별하게! 커스텀 디자인 케이크 마스터 클래스
# 1       009P43Kc7tTdx06F3BWmth3kZmr2  ...                         소자본 내방에서 창업한다 레터링풍선 클래스
# 2       00C8rFeEsmXmQSqo5rNSDJb2qGS2  ...  21년 개정판! 스마트스토어로 월 100만원 만들기, 평범한 사람이 돈을 만드는 비법
# 3       00C8rFeEsmXmQSqo5rNSDJb2qGS2  ...                    러셀과 함께 언리얼 엔진으로 나만의 가상 세계 만들기
# 4       00C8rFeEsmXmQSqo5rNSDJb2qGS2  ...         3D 게임 제작에서 사용하는 가상 환경, 사진 찍어서 직접 만들어 보세요
# ...                              ...  ...                                              ...
# 984141  zzsmvxfQy6hjXv3z2JBeAnEePfE3  ...  21년 개정판! 스마트스토어로 월 100만원 만들기, 평범한 사람이 돈을 만드는 비법
# 984142  zzvKLMu4YnbTZSwe4FcvRwnmxf22  ...                    전통의 아름다움, 메종드윤과 함께 만드는 한복 장신구
# 984143  zzy4WT7rKDZ4at8kPN2upPUyqGg2  ...                  다양한 색으로 과감하게 그려보는 콰야의 오일파스텔 드로잉
# ...

# %%
df_up = df.loc[:,['user_f_id','product_f_id']].copy()

# %%
products = df_up.set_index('user_f_id').stack().groupby('user_f_id').apply(list).to_dict()

# %%
#list(map(lambda x: set(x) , products.values()))

# %%
products_list = sorted( list(map(lambda x: list(set(x)) , products.values())), key=lambda item: len(item), reverse=False)[13380:]

# %%
import itertools

# %%
edges=  sum( [ list(itertools.combinations(x,2)) for x in products_list ] ,[])

# %%
edges
# Out:
# [('jIC7QRa4oeFi2E1W39gi', 'l20zpmgOWoNPBk5PMBaQ'),
#  ('LlVNj3EWgERhNX4tDrua', 'NpD5SSy1dAIoe9rFrIA0'),
#  ('DiyaOKpLFulcHhiRncVt', 'R38sGT9W1TuFuerrUoYy'),
#  ('6PhjgFl7CldOCg7yv6mX', 'ENppV01t0eGcUoEl1TYq'),
#  ('tk9ZcndBfpAWMkcSuln9', 'm3ig53oKWBbIFhwmAZPj'),
#  ('qQimLOeiWDhccVeuzVNu', '4H3dwNHUqghUFCzc6hRb'),
#  ('YxoLEEDOqDUH3NZ1PBJ0', 'FO3HfVZtXTo23QVhaJFX'),
#  ('j2cqasKulOEI8EtcgWmd', 'ssvJ8xm8Hu9DNE80x37x'),
#  ('0qfjBwNLop9bhoAQqfkg', '0OHbRDXnYFWigCuwxXHQ'),
#  ('w49Vcr0LLiqtOgrdSWRy', 'GJ23SqCq9Sr24wmgVE7H'),
#  ('tM1lCXRFBFkAdY7VFIDv', 'BjkCb7AJ62j1x7nZ0yaM'),
#  ('0384462CF31FEA26AF51A2', 'v2LrqmCCf1JWL4F38OC6'),
#  ('DOw51Zm5X55Luh38rTp3', 'koreagrandma'),
#  ('4SWvrLYozwbAyHBvjfhe', 'ClwwIYZSELEklIAie7uB'),
#  ('vtvR2OlAgEXy03YNhdx3', 'VqrEyNm59NfvYYEDQi41'),
#  ('UZXB7FMrLhG67BEPwwhq', 'UwRA4Xc7lsiSqeSxU33k'),
#  ('jwxIXZIlh17wi5xN65Do', 'qx6wbF2nnq5i6iPxYe5X'),
#  ('WSbm0jnqkNS0SHyVesna', 'JVvhfcSMZTFVkOyKuFy7'),
# ...

# %%
len(edges)
# Out:
# 102365

# %%
products_list
# Out:
# [{'jIC7QRa4oeFi2E1W39gi', 'l20zpmgOWoNPBk5PMBaQ'},
#  {'LlVNj3EWgERhNX4tDrua', 'NpD5SSy1dAIoe9rFrIA0'},
#  {'DiyaOKpLFulcHhiRncVt', 'R38sGT9W1TuFuerrUoYy'},
#  {'6PhjgFl7CldOCg7yv6mX', 'ENppV01t0eGcUoEl1TYq'},
#  {'m3ig53oKWBbIFhwmAZPj', 'tk9ZcndBfpAWMkcSuln9'},
#  {'4H3dwNHUqghUFCzc6hRb', 'qQimLOeiWDhccVeuzVNu'},
#  {'FO3HfVZtXTo23QVhaJFX', 'YxoLEEDOqDUH3NZ1PBJ0'},
#  {'j2cqasKulOEI8EtcgWmd', 'ssvJ8xm8Hu9DNE80x37x'},
#  {'0OHbRDXnYFWigCuwxXHQ', '0qfjBwNLop9bhoAQqfkg'},
#  {'GJ23SqCq9Sr24wmgVE7H', 'w49Vcr0LLiqtOgrdSWRy'},
#  {'BjkCb7AJ62j1x7nZ0yaM', 'tM1lCXRFBFkAdY7VFIDv'},
#  {'0384462CF31FEA26AF51A2', 'v2LrqmCCf1JWL4F38OC6'},
#  {'DOw51Zm5X55Luh38rTp3', 'koreagrandma'},
#  {'4SWvrLYozwbAyHBvjfhe', 'ClwwIYZSELEklIAie7uB'},
#  {'VqrEyNm59NfvYYEDQi41', 'vtvR2OlAgEXy03YNhdx3'},
#  {'UZXB7FMrLhG67BEPwwhq', 'UwRA4Xc7lsiSqeSxU33k'},
#  {'jwxIXZIlh17wi5xN65Do', 'qx6wbF2nnq5i6iPxYe5X'},
#  {'JVvhfcSMZTFVkOyKuFy7', 'WSbm0jnqkNS0SHyVesna'},
# ...
